# %% [markdown]
# <a href="https://colab.research.google.com/github/Raghava-1845/NNDL-6/blob/main/grayscale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image

# Open the image
img = Image.open("heart.jpg")

# Convert RGB to grayscale
gray = img.convert("L")

# Display side by side
plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
plt.imshow(img)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(gray, cmap="gray")
plt.title("Grayscale Image")
plt.axis("off")

plt.show()

print("Grayscale image saved successfully")
# Out:
# Grayscale image saved successfully
